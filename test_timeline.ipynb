# %%
import xmltodict
import bokeh
import re
import datetime

# %%
# function definitions

# rex pattern to match the log file timestamp
ts_rexp = '^(\d{4}-\d{2}-\d{2})\s(\d{2}:\d{2}:\d{2})'

def parse_start_time(stdout):
    for line in so.splitlines():
        match = re.match(ts_rexp, so.splitlines()[0])
        if match is not None:
            return '{0}T{1}'.format(match[1], match[2])


def parse_times(test, setup=False):
    tdc_from = td_from = t_from = sc_from = s_from = sc_to = s_to = td_to = tdc_to = t_to = None
    if test.get('properties'):
        t_from = calc_time(test['properties']['property']['@value'])
        t_to = calc_time(test['properties']['property']['@value'], test['@time'])

    for line in test['system-out'].splitlines():
        if not setup:
            match = re.match(ts_rexp, line)
            t_from = calc_time('{0}T{1}'.format(match[1], match[2]))
        
        # let's search for 'SetupClass' messages
        if not sc_from:
            sc_match = re.match(ts_rexp + '[^$]*(Started setUpClass:)', line)
            if sc_match:
                sc_from = calc_time('{0}T{1}'.format(sc_match[1], sc_match[2]))
        if not s_from:
            s_match = re.match(ts_rexp + '[^$]*(Started setUp:)', line)
            if s_match:
                s_from = sc_to = calc_time('{0}T{1}'.format(s_match[1], s_match[2]))
        if not t_from:
            t_match = re.match(ts_rexp + '[^$]*(Started Test)', line)
            if t_match:
                t_from = calc_time('{0}T{1}'.format(t_match[1], t_match[2]))
                if s_from:
                    s_to = calc_time('{0}T{1}'.format(t_match[1], t_match[2]))
                else:
                    sc_to = calc_time('{0}T{1}'.format(t_match[1], t_match[2]))
        if not td_from:
            td_match = re.match(ts_rexp + '[^$]*(Started tearDown:)', line)
            if td_match:
                td_from = calc_time('{0}T{1}'.format(td_match[1], td_match[2]))
                t_to = td_from
        if not tdc_from:
            tdc_match = re.match(ts_rexp + '[^$]*(Started tearDownClass:)', line)
            if tdc_match:
                tdc_from = calc_time('{0}T{1}'.format(tdc_match[1], tdc_match[2]))
                if not t_to:
                    t_to = tdc_from
        return {
            'setupclass': {'from': sc_from, 'to': sc_to},
            'setup': {'from': s_from, 'to': s_to},
            'test': {'from': t_from, 'to': t_to},
            'teardown': {'from': td_from, 'to': td_to},
            'teardownclass': {'from': tdc_from, 'to': tdc_to},
        }

        
def calc_time(st, d=0):
    '''returns a datetime object representation of the passed datetime string with added duration time
    :param st: string in %Y-%m-%dT%H:%M:%S format
    :param d: string or number representing the duration in seconds
    '''
    s = datetime.datetime.strptime(st, '%Y-%m-%dT%H:%M:%S')
    return s+datetime.timedelta(0,float(d))

# %%
# load the xml file
with open('junits/tier1-parallel-results.xml', 'r') as f:
    t1p = xmltodict.parse(f.read())['testsuite']

# %%
testcases = [
    {'duration': parse_times(n),
     'name': n['@name'],
     'class': n['@classname'],
     
    } for n in t1p['testcase']] #if not n.get('properties')]

testcases
# Out:
# [{'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 38, 204000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_auto_attach',
#   'class': 'tests.foreman.api.test_activationkey.ActivationKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 38, 890000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_activationkey.ActivationKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 19, 874000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_unlimited_hosts',
#   'class': 'tests.foreman.api.test_activationkey.ActivationKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 9, 666000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_name',
#   'class': 'tests.foreman.api.test_architecture.ArchitectureTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 7, 287000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_name',
#   'class': 'tests.foreman.api.test_architecture.ArchitectureTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 19, 239000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_limited_hosts',
#   'class': 'tests.foreman.api.test_activationkey.ActivationKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 38, 209000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_activationkey.ActivationKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 7),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 7),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 42, 309000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_empty_query',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 10),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 10),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 44, 552000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_null_public',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 19),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 19),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 19, 249000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_architecture.ArchitectureTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 20),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 20),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 21, 26000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_architecture.ArchitectureTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 20),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 20),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 54, 330000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_same_name',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 21),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 21),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 53, 666000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_name',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 54, 54),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 11, 280000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_search_by_org',
#   'class': 'tests.foreman.api.test_activationkey.ActivationKeySearchTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 33),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 33),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 46, 704000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_by_type',
#   'class': 'tests.foreman.api.test_audit.AuditTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 38),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 38),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 2, 51000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete_by_type',
#   'class': 'tests.foreman.api.test_audit.AuditTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 38),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 38),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 38, 427000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_architecture.ArchitectureTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 39),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 39),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 1, 595000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_by_type',
#   'class': 'tests.foreman.api.test_audit.AuditTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 40),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 47, 615000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_query',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 41),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 51, 398000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 39),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 39),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 58, 879000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_empty_query',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 48),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 48),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 48, 247000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_computeprofile.ComputeProfileTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 48),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 48),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 59, 42000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_composite',
#   'class': 'tests.foreman.api.test_contentview.ContentViewCreateTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 50),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 4, 24000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 47),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 47),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 6, 444000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_public',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 51),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 12, 592000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_public',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 51),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 51),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 51, 306000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_computeprofile.ComputeProfileTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 51),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 51),
#     'to': datetime.datetime(2019, 10, 4, 15, 55, 55, 671000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_clone',
#   'class': 'tests.foreman.api.test_contentview.ContentViewCreateTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 56),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 9, 839000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_query',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 56),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 56), 'to': None},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_search_erratum',
#   'class': 'tests.foreman.api.test_contentviewfilter.ContentViewFilterSearchTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 59),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 59),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 0, 27000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_disable',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 4),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 4),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 4, 136000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_computeprofile.ComputeProfileTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 4),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 4),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 9, 620000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_name',
#   'class': 'tests.foreman.api.test_contentview.ContentViewCreateTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 2),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 2),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 22, 579000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_invalid_name',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 18, 537000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_docker.DockerRepositoryTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 55, 59),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 55, 59),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 11, 208000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_search_package_group',
#   'class': 'tests.foreman.api.test_contentviewfilter.ContentViewFilterSearchTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 2),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 2),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 27, 83000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_same_name',
#   'class': 'tests.foreman.api.test_bookmarks.BookmarkTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 5),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 5),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 6, 929000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_host_limit',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 9),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 9),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 20, 334000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_contentview.ContentViewDeleteTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 4),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 4),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 18, 223000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_description',
#   'class': 'tests.foreman.api.test_computeresource_libvirt.ComputeResourceTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 6),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 6),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 45, 385000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_sync',
#   'class': 'tests.foreman.api.test_docker.DockerRepositoryTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 11),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 11),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 16, 945000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_description',
#   'class': 'tests.foreman.api.test_contentview.ContentViewCreateTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 9),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 9),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 24, 421000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_provider',
#   'class': 'tests.foreman.api.test_computeresource_libvirt.ComputeResourceTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 12),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 12),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 22, 440000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_computeresource_libvirt.ComputeResourceTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 18),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 18),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 27, 432000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_contentview.ContentViewCreateTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 20),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 20),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 20, 126000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create',
#   'class': 'tests.foreman.api.test_computeprofile.ComputeProfileTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 13),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 13),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 28, 723000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_org_and_loc',
#   'class': 'tests.foreman.api.test_environment.EnvironmentTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 21, 702000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 17),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 17),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 25, 412000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_name',
#   'class': 'tests.foreman.api.test_contentview.ContentViewUpdateTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 21, 281000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_priority',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 22),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 22, 473000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_search_rule',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 17),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 17),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 29, 304000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_search_rpm',
#   'class': 'tests.foreman.api.test_contentviewfilter.ContentViewFilterSearchTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 23),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 23),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 24, 861000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 24),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 24),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 24, 284000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_name',
#   'class': 'tests.foreman.api.test_computeprofile.ComputeProfileTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 36, 182000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_content',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 21),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 37, 42000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_upstream_name',
#   'class': 'tests.foreman.api.test_docker.DockerRepositoryTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 27),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 27),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 27, 257000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_host_limit',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 27),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 35, 854000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_org_loc',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 22),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 22),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 35, 997000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_characters',
#   'class': 'tests.foreman.api.test_environment.EnvironmentTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 29),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 29),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 29, 511000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete_role',
#   'class': 'tests.foreman.api.test_filter.FilterTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 24),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 24),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 43, 18000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_docker.DockerRepositoryTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 20),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 20),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 41, 771000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_computeresource_libvirt.ComputeResourceTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 31),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 39, 344000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_search_in_org',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 25),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 25),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 41, 967000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_computeresource_libvirt.ComputeResourceTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 30),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 30),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 41, 21000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_same_name',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 37),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 37),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 37, 287000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_permission',
#   'class': 'tests.foreman.api.test_filter.FilterTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 31),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 31),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 45, 200000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_attributes',
#   'class': 'tests.foreman.api.test_contentview.ContentViewUpdateTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 31),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 31),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 46, 796000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_environment.EnvironmentTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 34),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 34),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 46, 42000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_contentview.ContentViewUpdateTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 39),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 39),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 39, 433000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_too_long_name',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 41),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 41),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 41, 531000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_discoveryrule.DiscoveryRuleTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 36),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 36),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 53, 789000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_upstream_name',
#   'class': 'tests.foreman.api.test_docker.DockerRepositoryTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 39),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 39),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 53, 327000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_name',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 38),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 38),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 49, 36000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_content',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 44),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 45, 37000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 40),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 40),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 55, 561000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_upstream_name',
#   'class': 'tests.foreman.api.test_docker.DockerRepositoryTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 41),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 41),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 58, 878000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_docker.DockerRepositoryTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 49),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 49),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 49, 476000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_filter.FilterTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 50),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 50, 294000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 50),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 50),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 0, 892000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_name',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 49),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 49),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 6, 972000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_too_long_name',
#   'class': 'tests.foreman.api.test_environment.EnvironmentTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 58),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 58),
#     'to': datetime.datetime(2019, 10, 4, 15, 56, 58, 58000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_fetch_non_existent_task',
#   'class': 'tests.foreman.api.test_foremantask.ForemanTaskTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 53),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 53),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 13, 519000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_name',
#   'class': 'tests.foreman.api.test_environment.EnvironmentTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 57, 4),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 4),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 4, 65000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_get_summary',
#   'class': 'tests.foreman.api.test_foremantask.ForemanTaskTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 56, 58),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 58),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 12, 164000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_content',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 57, 4),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 4),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 14, 684000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_gpgkey.GPGKeyTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 56, 36),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 8, 925000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_mac',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 28),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 36, 405000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 36),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 45, 899000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_read_puppet_proxy_name',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 46),
#     'to': datetime.datetime(2019, 10, 4, 15, 57, 55, 268000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 17),
#     'to': datetime.datetime(2019, 10, 4, 15, 59, 1, 433000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_comment',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 1),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 9, 21000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_puppet_proxy',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 57, 55),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 55),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 10, 956000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_host.HostInterfaceTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 9),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 29, 54000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_enabled_parameter',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 58, 3),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 3),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 25, 760000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_limit',
#   'class': 'tests.foreman.api.test_hostcollection.HostCollectionTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 15),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 15, 374000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_host',
#   'class': 'tests.foreman.api.test_hostcollection.HostCollectionTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 57, 50),
#     'to': datetime.datetime(2019, 10, 4, 16, 0, 0, 737000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_owner_type',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 58, 15),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 15),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 28, 610000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.api.test_hostgroup.HostGroupTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 58, 22),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 22),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 34, 919000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.api.test_lifecycleenvironment.LifecycleEnvironmentTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 29),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 30, 855000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_puppet_class',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 58, 29),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 29),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 43, 294000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_invalid_name',
#   'class': 'tests.foreman.api.test_media.MediaTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 36),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 36, 451000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete',
#   'class': 'tests.foreman.api.test_media.MediaTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 15, 58, 36),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 36),
#     'to': datetime.datetime(2019, 10, 4, 16, 0, 7, 526000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete_and_get_requests',
#   'class': 'tests.foreman.api.test_multiple_paths.DoubleCheckTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 15, 58, 37),
#     'to': datetime.datetime(2019, 10, 4, 15, 58, 44, 633000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_managed_parameter',
#   'class': 'tests.foreman.api.test_host.HostTestCase'},
# ...
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 42),
#     'to': datetime.datetime(2019, 10, 4, 16, 19, 51, 527000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_update_by_id',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 44),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 5, 486000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_username',
#   'class': 'tests.foreman.cli.test_user.UserWithCleanUpTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 44),
#     'to': datetime.datetime(2019, 10, 4, 16, 19, 58, 254000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_list_filters_by_name',
#   'class': 'tests.foreman.cli.test_role.RoleTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 47),
#     'to': datetime.datetime(2019, 10, 4, 16, 19, 56, 493000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_role_name',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 48),
#     'to': datetime.datetime(2019, 10, 4, 16, 19, 52, 787000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 51),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 14, 684000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_roles',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 53),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 2, 575000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_usergroup_id',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 16, 19, 55),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 55),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 4, 578000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_role_id',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 56),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 5, 423000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_user_name',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 19, 58),
#     'to': datetime.datetime(2019, 10, 4, 16, 45, 31, 420000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_list_filters_with_pagination',
#   'class': 'tests.foreman.cli.test_role.RoleTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 1),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 15, 174000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_exported_cvv_json_contents',
#   'class': 'tests.foreman.cli.test_satellitesync.ContentViewSync'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 2),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 21, 51000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_usergroups',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 5),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 34, 585000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_users',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 16, 20, 5),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 5),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 14, 554000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_user_id',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 6),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 15, 516000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete_by_id',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 15),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 24, 509000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_list',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 15),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 24, 472000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_usergroup_name',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 15),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 24, 471000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_by_id',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 16, 20, 15),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 15),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 46, 172000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_CRUD',
#   'class': 'tests.foreman.cli.test_subnet.SubnetTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 22),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 31, 523000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete_by_name',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 24),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 33, 551000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_by_name',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 34),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 48, 238000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_delete_with_user_by_id',
#   'class': 'tests.foreman.cli.test_usergroup.UserGroupTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 34),
#     'to': datetime.datetime(2019, 10, 4, 16, 24, 1, 175000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_end_to_end',
#   'class': 'tests.foreman.ui.test_computeresource_vmware'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 16, 20, 49),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 49), 'to': None},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_validate_katello_certs_check_output',
#   'class': 'tests.foreman.sys.test_katello_certs_check.KatelloCertsCheckTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 16, 20, 49),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 49),
#     'to': datetime.datetime(2019, 10, 4, 16, 20, 56, 788000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_foreman_module',
#   'class': 'tests.foreman.installer.test_installer.SELinuxTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 20, 25),
#     'to': datetime.datetime(2019, 10, 4, 16, 23, 10, 687000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_CRUD',
#   'class': 'tests.foreman.cli.test_variables.SmartVariablesTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 21, 56),
#     'to': datetime.datetime(2019, 10, 4, 16, 26, 1, 473000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_end_to_end',
#   'class': 'tests.foreman.ui.test_oscapcontent'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 16, 22, 26),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 22, 26),
#     'to': datetime.datetime(2019, 10, 4, 16, 22, 35, 553000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_name',
#   'class': 'tests.foreman.cli.test_user.UserTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 22, 35),
#     'to': datetime.datetime(2019, 10, 4, 16, 22, 52, 455000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_org',
#   'class': 'tests.foreman.cli.test_user.UserTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 21, 39),
#     'to': datetime.datetime(2019, 10, 4, 16, 25, 28, 302000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_duplicate_name_variable',
#   'class': 'tests.foreman.cli.test_variables.SmartVariablesTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 23),
#     'to': datetime.datetime(2019, 10, 4, 16, 24, 48, 675000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_negative_create_with_same_name',
#   'class': 'tests.foreman.ui.test_oscapcontent'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 23, 53),
#     'to': datetime.datetime(2019, 10, 4, 16, 25, 28, 620000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_end_to_end',
#   'class': 'tests.foreman.ui.test_oscaptailoringfile'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 22, 53),
#     'to': datetime.datetime(2019, 10, 4, 16, 27, 51, 929000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_add_and_remove_matcher',
#   'class': 'tests.foreman.cli.test_variables.SmartVariablesTestCase'},
#  {'duration': {'setupclass': {'from': datetime.datetime(2019, 10, 4, 16, 24, 26),
#     'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 24, 26),
#     'to': datetime.datetime(2019, 10, 4, 16, 24, 49, 345000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_check_installer_services',
#   'class': 'tests.foreman.installer.test_installer.SELinuxTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 24, 12),
#     'to': datetime.datetime(2019, 10, 4, 16, 30, 23, 909000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_create_with_default_value',
#   'class': 'tests.foreman.cli.test_variables.SmartVariablesTestCase'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 25, 30),
#     'to': datetime.datetime(2019, 10, 4, 16, 27, 48, 982000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_end_to_end',
#   'class': 'tests.foreman.ui.test_oscappolicy'},
#  {'duration': {'setupclass': {'from': None, 'to': None},
#    'setup': {'from': None, 'to': None},
#    'test': {'from': datetime.datetime(2019, 10, 4, 16, 45, 32),
#     'to': datetime.datetime(2019, 10, 4, 16, 45, 41, 690000)},
#    'teardown': {'from': None, 'to': None},
#    'teardownclass': {'from': None, 'to': None}},
#   'name': 'test_positive_update_name',
#   'class': 'tests.foreman.cli.test_role.RoleTestCase'}]
